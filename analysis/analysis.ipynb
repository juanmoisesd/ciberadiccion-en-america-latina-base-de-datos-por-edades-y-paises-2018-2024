# %% [markdown]
# # Ciberadicción en América Latina: Base de Datos por Edades y Países (2018-2024)
#
# **DOI:** [10.5281/zenodo.18880635](https://doi.org/10.5281/zenodo.18880635)
# **Author:** de la Serna Tuya, Juan Moisés · ORCID: 0000-0002-8401-8018
# **License:** CC0 1.0
#
# ---
#
# Base de datos sobre ciberadicción (adicción a internet, redes sociales y videojuegos) en América Latina, con estadísticas organizadas por grupos de edad (niños, adolescentes, adultos jóvenes, adultos, adultos mayores) y por países (México, Brasil, Argentina, Colombia, Chile, Perú, Ecuador, Bolivia, Paraguay, Uruguay, Venezuela, Costa Rica, Guatemala, Honduras, Panamá, República Dominicana). Datos
#
# **Keywords:** ciberadicción

# %%
# Install dependencies if needed
# !pip install pandas matplotlib seaborn numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120
print('Libraries loaded.')

# %% [markdown]
# ## 1. Load Dataset

# %%
# Download from: https://doi.org/10.5281/zenodo.18880635
# df = pd.read_csv('dataset.csv')

# Synthetic example data
np.random.seed(42)
years = list(range(2000, 2024))
keywords = ['ciberadicción']
df = pd.DataFrame({'year': years,
    **{k.replace(' ','_')[:12]: np.random.normal(50,15,len(years)) for k in keywords}})

print(f'Dataset: Ciberadicción en América Latina: Base de Datos por')
print(f'DOI: 10.5281/zenodo.18880635')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## 2. Summary Statistics

# %%
df.describe().round(2)

# %% [markdown]
# ## 3. Temporal Trends

# %%
fig, ax = plt.subplots(figsize=(10,5))
for col in df.columns[1:]:
    ax.plot(df['year'], df[col], marker='o', markersize=3, label=col)
ax.set_title('Ciberadicción en América Latina: Base de Datos por Edad')
ax.set_xlabel('Year')
ax.set_ylabel('Value')
ax.legend(fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Citation

# %%
print('APA:')
print('de la Serna Tuya, Juan Moisés (2026). Ciberadicción en América Latina: Base de Datos por Edades y Países (20. Zenodo. https://doi.org/10.5281/zenodo.18880635')
